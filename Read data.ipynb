# %%
import pandas as pd

csv_path = "adultobesity.csv"

adult_data = pd.read_csv(csv_path)

adult_data.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc  \
# 0       2017     2017           WA     Washington
# 1       2017     2017           MA  Massachusetts
# 2       2017     2017           KY       Kentucky
# 3       2017     2017           VT        Vermont
# 4       2017     2017           NM     New Mexico
#
#                                    Datasource                  Class  \
# 0  Behavioral Risk Factor Surveillance System  Fruits and Vegetables
# 1  Behavioral Risk Factor Surveillance System  Fruits and Vegetables
# 2  Behavioral Risk Factor Surveillance System  Fruits and Vegetables
# 3  Behavioral Risk Factor Surveillance System  Fruits and Vegetables
# 4  Behavioral Risk Factor Surveillance System  Fruits and Vegetables
#
#                               Topic  \
# 0  Fruits and Vegetables - Behavior
# 1  Fruits and Vegetables - Behavior
# 2  Fruits and Vegetables - Behavior
# 3  Fruits and Vegetables - Behavior
# 4  Fruits and Vegetables - Behavior
#
# ...

# %%
# grouped_adult_data = adult_data.groupby(["LocationDesc"])
# grouped_adult_data.head()
# grouped_adult_data.count()["LocationDesc"]

adult_obesity = adult_data.loc[(adult_data["QuestionID"] == "Q036") & (adult_data["YearStart"] == 2020) & (adult_data["StratificationCategoryId1"] == "INC")].reset_index(drop = "True")

# categories = adult_obesity["Stratification1"].unique()

# categories

# adult_fruit_consumption = pd.DataFrame(columns = ["Male", "Female", ""])

adult_obesity.head()
# Out:
#    YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0       2020     2020           PR     Puerto Rico
# 1       2020     2020           NV          Nevada
# 2       2020     2020           SC  South Carolina
# 3       2020     2020           OK        Oklahoma
# 4       2020     2020           MD        Maryland
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
adult_obesity.groupby()
# Out:
#      YearStart  YearEnd LocationAbbr   LocationDesc  \
# 0         2020     2020           AL        Alabama
# 1         2020     2020           GA        Georgia
# 2         2020     2020           MA  Massachusetts
# 3         2020     2020           PR    Puerto Rico
# 4         2020     2020           PR    Puerto Rico
# ..         ...      ...          ...            ...
# 326       2020     2020           ME          Maine
# 330       2020     2020           KY       Kentucky
# 337       2020     2020           MS    Mississippi
# 347       2020     2020           AR       Arkansas
# 376       2020     2020           AR       Arkansas
#
#                                      Datasource                    Class  \
# 0    Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1    Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2    Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
poverty_csv = "poverty_stats/poverty_csv"

poverty_data = pd.read_csv(poverty_csv)

poverty_data.head()
# Out:
#    Year  State FIPS Postal Code           Name  Poverty Percent All Ages  \
# 0  2003           0          US  United States                      12.5
# 1  2004           0          US  United States                      12.7
# 2  2005           0          US  United States                      13.3
# 3  2006           0          US  United States                      13.3
# 4  2007           0          US  United States                      13.0
#
#   Median Household Income Poverty Estimate Ages 5-17  \
# 0                  43,318                  8,399,573
# 1                  44,334                  8,430,886
# 2                   46242                    8765541
# 3                   48451                    8700048
# 4                   50740                    8499844
#
#    Poverty Percent Ages 5-17
# 0                       16.1
# 1                       16.2
# 2                       17.0
# 3                       16.7
# 4                       16.4

# %%
state_capitals_csv = "poverty_stats/us-state-capitals.csv"

capitals = pd.read_csv(state_capitals_csv)

capitals.rename(["origi"])
# Out:
#        origin     blahblah   latitude   longitude
# 0         ATL        12.35  33.636666  -84.428066
# 1     Arizona      Phoenix  33.448143 -112.096962
# 2    Arkansas  Little Rock  34.746613  -92.288986
# 3  California   Sacramento  38.576668 -121.493629
# 4    Colorado       Denver  39.739227 -104.984856

# %%
heatmap_poverty = pd.merge(poverty_data, capitals, on = [])
